# %%
import pandas as pd
import numpy as np
import os, time,json
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook

basics = pd.read_csv("Data/title_basics.csv.gz")

# %%
def get_movie_with_rating(movie_id):
    movie = tmdb.Movies(movie_id)
# save the .info .releases dictionaries
    info = movie.info()
    releases = movie.releases()
# Loop through countries in releases
    for c in releases['countries']:
    # if the country abbreviation==US
        if c['iso_3166_1' ] =='US':
        ## save a "certification" key in the info dict with the certification
            info['certification'] = c['certification']
    return info

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)# filter out any ids that are already in the JSON_FILE

# %%
with open('/Users/spart/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
tmdb.API_KEY =  login["api-key"]

# %%
test_ids = ["tt0848228", "tt0332280"]
results = []
for movie_id in test_ids:
    
    try:
        movie_info = get_movie_with_rating(movie_id)
        results.append(movie_info)
        
    except: 
        pass
    
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path  \
# 0  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 1  False  /qom1SZSENdmHFNZBXbtJAU0WTlC.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  220000000
# 1                                               None   29000000
#
#                                               genres  \
# 0  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                             homepage     id    imdb_id  \
# 0         https://www.marvel.com/movies/the-avengers  24428  tt0848228
# 1  http://www.newline.com/properties/notebookthe....  11036  tt0332280
#
#   original_language original_title  ...     revenue  runtime  \
# 0                en   The Avengers  ...  1518815515      143
# 1                en   The Notebook  ...   115603229      123
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline         title  video  \
# 0                    Some assembly required.  The Avengers  False
# 1  Behind every great love is a great story.  The Notebook  False
#
#    vote_average vote_count certification
# 0         7.707      28400         PG-13
# 1         7.877      10234         PG-13
#
# [2 rows x 26 columns]

# %%
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz',
#  'tmdb_api_results_2000.json']

# %%
YEARS_TO_GET = [2000,2001]

# %%
errors = [ ]

# %%
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    
    file_exists = os.path.isfile(JSON_FILE)
    
    df = basics.loc[basics['startYear'] == YEAR].copy()
    
    movie_ids = df['tconst'].copy()
    
    previous_df = pd.read_json(JSON_FILE)
    
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]
    
    if file_exists == False:
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)

    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            temp = get_movie_with_rating(movie_id)  
            write_json(temp,JSON_FILE)
            time.sleep(0.02)
            
        except Exception as e:
            errors.append([movie_id, e])
            
    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]
# Movies from 2000:   0%|          | 0/210 [00:00<?, ?it/s]
# Movies from 2001:   0%|          | 0/1558 [00:00<?, ?it/s]

# %%
print(f"- Total errors: {len(errors)}")

# %%
final2000 = pd.read_csv("Data/final_tmdb_data_2000.csv.gz")
final2000
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 4996  tt6174238    0.0                               NaN
# 4997  tt7029820    0.0                               NaN
# 4998  tt7197642    0.0                               NaN
# 4999  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 5000  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...                    ...         ...
# 4996                   NaN         0.0
# 4997                   NaN      7000.0
# 4998                   NaN         0.0
# 4999                   NaN  10000000.0
# 5000                   NaN         0.0
#
#                                                  genres homepage        id  \
# 0                                                   NaN      NaN       NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 2              [{'id': 878, 'name': 'Science Fiction'}]      NaN  110977.0
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN  442869.0
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN     843.0
# ...                                                 ...      ...       ...
# 4996                      [{'id': 80, 'name': 'Crime'}]      NaN  223878.0
# 4997                                                 []      NaN  604889.0
# 4998                     [{'id': 35, 'name': 'Comedy'}]      NaN  872676.0
# 4999                     [{'id': 27, 'name': 'Horror'}]      NaN   97186.0
# 5000  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      NaN  610992.0
#
#      original_language           original_title  ...     revenue  runtime  \
# 0                  NaN                      NaN  ...         NaN      NaN
# 1                   en          The Fantasticks  ...         0.0     86.0
# 2                   en            For the Cause  ...         0.0    100.0
# 3                   hi                     Gang  ...         0.0    152.0
# 4                   cn                     花樣年華  ...  12854953.0     99.0
# ...                ...                      ...  ...         ...      ...
# 4996                cn                       冷战  ...         0.0      0.0
# 4997                en     Scream For Christmas  ...         0.0     80.0
# 4998                en  Goodbye, Merry-Go-Round  ...         0.0     90.0
# 4999                fr               I, Vampire  ...         0.0     85.0
# 5000                fa                مومیایی ۳  ...         0.0     98.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# ...                                                 ...       ...
# 4996  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4997                                                 []  Released
# 4998                                                 []  Released
# 4999  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5000  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1         Try to remember the first time magic happened
# 2          The ultimate showdown on a forbidden planet.
# 3                                                   NaN
# 4     Feel the heat, keep the feeling burning, let t...
# ...                                                 ...
# 4996                                                NaN
# 4997                                                NaN
# 4998                                                NaN
# 4999                                                NaN
# 5000                                                NaN
#
#                         title  video  vote_average vote_count certification
# 0                         NaN    NaN           NaN        NaN           NaN
# 1             The Fantasticks    0.0          5.50       22.0           NaN
# 2               For the Cause    0.0          5.10        8.0           NaN
# 3                        Gang    0.0          4.00        1.0           NaN
# 4        In the Mood for Love    0.0          8.11     2162.0            PG
# ...                       ...    ...           ...        ...           ...
# 4996                 Cold War    0.0          2.00        2.0           NaN
# 4997     Scream For Christmas    0.0          0.00        0.0           NaN
# 4998  Goodbye, Merry-Go-Round    0.0          0.00        0.0           NaN
# 4999               I, Vampire    0.0          6.40        4.0            NR
# 5000              The Mummy 3    0.0          7.00        1.0           NaN
#
# [5001 rows x 26 columns]

# %%
final2001 = pd.read_csv("Data/final_tmdb_data_2001.csv.gz")
final2001
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2     tt0114447    0.0                               NaN
# 3     tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# 4     tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg
# ...         ...    ...                               ...
# 1312  tt7797670    0.0                               NaN
# 1313  tt7797790    0.0                               NaN
# 1314  tt8665056    0.0                               NaN
# 1315  tt8795764    0.0                               NaN
# 1316  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN  22000000.0
# 4                      NaN   1000000.0
# ...                    ...         ...
# 1312                   NaN         0.0
# 1313                   NaN         0.0
# 1314                   NaN         0.0
# 1315                   NaN         0.0
# 1316                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...
# 2     [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 4     [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# ...                                                 ...
# 1312                     [{'id': 27, 'name': 'Horror'}]
# 1313                     [{'id': 27, 'name': 'Horror'}]
# 1314                    [{'id': 37, 'name': 'Western'}]
# 1315                     [{'id': 27, 'name': 'Horror'}]
# 1316                     [{'id': 28, 'name': 'Action'}]
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN   11232.0
# 2                                                   NaN  151007.0
# 3                                                   NaN   10696.0
# 4                                                   NaN   17140.0
# ...                                                 ...       ...
# 1312                                                NaN  956214.0
# 1313                                                NaN  956219.0
# 1314  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 1315  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 1316                                                NaN  201706.0
#
#      original_language                              original_title  ...  \
# 0                  NaN                                         NaN  ...
# 1                   en                              Kate & Leopold  ...
# 2                   en                            The Silent Force  ...
# 3                   en                                     Glitter  ...
# 4                   en                       The Attic Expeditions  ...
# ...                ...                                         ...  ...
# 1312                en  Edmund Kemper Part 2: La Mort C'est La Vie  ...
# 1313                en         Edmund Kemper Part 3: La mort sévit  ...
# 1314                en                        Guns Along The Bravo  ...
# 1315                en                                   New Breed  ...
# 1316                cn                                        致命密函  ...
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1     76019048.0    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      5271666.0    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4            0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 1312         0.0     91.0                                                 []
# 1313         0.0     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 1314         0.0     85.0                                                 []
# 1315         0.0     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1316         0.0     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released  If they lived in the same century, they'd be p...
# 2     Released  They left him for dead... They should have fin...
# 3     Released   In music she found her dream, her love, herself.
# 4     Released  His search for peace of mind... will leave his...
# ...        ...                                                ...
# 1312  Released                                                NaN
# 1313  Released                                                NaN
# 1314  Released  Evil came to the Southwest until three blazing...
# 1315  Released                                                NaN
# 1316  Released                                                NaN
#
#                                            title  video  vote_average  \
# 0                                            NaN    NaN           NaN
# 1                                 Kate & Leopold    0.0         6.328
# 2                               The Silent Force    0.0         5.000
# 3                                        Glitter    0.0         4.600
# 4                          The Attic Expeditions    0.0         5.100
# ...                                          ...    ...           ...
# 1312  Edmund Kemper Part 2: La Mort C'est La Vie    0.0         0.000
# 1313         Edmund Kemper Part 3: La mort sévit    0.0         0.000
# 1314                        Guns Along The Bravo    0.0         0.000
# 1315                                   New Breed    0.0         0.000
# 1316                              Chinese Heroes    0.0         3.000
#
#      vote_count certification
# 0           NaN           NaN
# 1        1181.0         PG-13
# 2           3.0           NaN
# 3         122.0         PG-13
# 4          29.0             R
# ...         ...           ...
# 1312        0.0           NaN
# 1313        0.0           NaN
# 1314        0.0           NaN
# 1315        0.0            NR
# 1316        2.0           NaN
#
# [1317 rows x 26 columns]
